# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 16 13:02:17 2018

@author: macchini
"""

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import utils

folder = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/Unity_data/experiments_new_dirty/simple'

info = 'interface_motive_method_maxmin'

useful_file_size_min = 900

baseline_folder = os.path.join(folder, 'baseline')
garbage_folder = os.path.join(folder, 'garbage')
maneuvers_folder = os.path.join(folder, 'maneuvers')
useless_folder = os.path.join(folder, 'useless')
freeflight_folder = os.path.join(folder, 'freeflight')

utils.create_dir_safe(baseline_folder)
utils.create_dir_safe(garbage_folder)
utils.create_dir_safe(maneuvers_folder)
utils.create_dir_safe(useless_folder)
utils.create_dir_safe(freeflight_folder)


files = utils.listdir_fullpath(folder)

for file in files:
    new_name = file[:]
    
    new_name = new_name.replace('torso', info)
    
    if 'user' not in new_name:
        new_name = new_name.replace('unity_history', info+'_user_unity_history')
        new_name = new_name.replace('control_history', info+'_user_control_history')
    
    new_name = new_name.replace('evaluation_manoeuvreList', 'file_maneuvers')
    new_name = new_name.replace('evaluation_TimeAngleRatePosRot', 'file_garbage')
    new_name = new_name.replace('evaluation_waypointDistTime', 'file_performance')
    
    if 'inst' not in new_name:
        new_name = new_name.replace('_0_', '_inst_0_')
        new_name = new_name.replace('_1_', '_inst_1_')
        new_name = new_name.replace('_2_', '_inst_2_')
        new_name = new_name.replace('_3_', '_inst_3_')
        new_name = new_name.replace('_4_', '_inst_4_')
        new_name = new_name.replace('_5_', '_inst_5_')
        new_name = new_name.replace('_6_', '_inst_6_')
        new_name = new_name.replace('_7_', '_inst_7_')
        
    if '_inst_4_' or '_inst_5_' or '_inst_6_' in new_name:
        new_name = new_name.replace('_inst_4_', '_inst_1_baseline_')
        new_name = new_name.replace('_inst_5_', '_inst_2_baseline_')
        new_name = new_name.replace('_inst_6_', '_inst_3_baseline_')
        
    
    os.rename(file, new_name)
    
    if 'file_garbage' in new_name:
        os.rename(new_name, os.path.join(garbage_folder, os.path.basename(new_name)))
    elif 'file_maneuvers' in new_name:
        os.rename(new_name, os.path.join(maneuvers_folder, os.path.basename(new_name)))
    elif '_baseline' in new_name:
        os.rename(new_name, os.path.join(baseline_folder, os.path.basename(new_name)))
    elif os.path.getsize(new_name) <  useful_file_size_min:
        os.rename(new_name, os.path.join(useless_folder, os.path.basename(new_name)))
    elif '_freeflight' in new_name:
        os.rename(new_name, os.path.join(freeflight_folder, os.path.basename(new_name)))

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 16 13:02:17 2018

@author: macchini
"""

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import utils

folder = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/Unity_data/experiments'

wrong = 'subect'
correct = 'subject'


files = utils.listdir_fullpath(folder)

for file in files:
    new_name = file[:]
    
    new_name = new_name.replace(wrong, correct)
    
    os.rename(file, new_name)

# %% [markdown]
# # remove third instances

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 16 13:02:17 2018

@author: macchini
"""

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import utils

folder = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/Unity_data/experiments'

third_folder = os.path.join(folder, 'third_instances')
utils.create_dir_safe(third_folder)

utils.create_dir_safe(baseline_folder)
utils.create_dir_safe(garbage_folder)
utils.create_dir_safe(maneuvers_folder)
utils.create_dir_safe(useless_folder)

files = utils.listdir_fullpath(folder)


for file in files:
    
    new_name = file[:]
    
    if 'inst_3' in new_name:
        os.rename(new_name, os.path.join(third_folder, os.path.basename(new_name)))

# %% [markdown]
# # clean motion data

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 16 13:02:17 2018

@author: macchini
"""

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import utils

folder = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp'

pilots = os.path.join(folder, 'pilots')
utils.create_dir_safe(pilots)

files = utils.listdir_fullpath(folder)

for file in files:
    
    new_name = file[:]
    
    if 'pilot' in new_name and 'pilots' not in new_name:
        os.rename(new_name, os.path.join(pilots, os.path.basename(new_name)))

# %%
new_name
# Out:
# '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/pilots'

# %%
files
# Out:
# ['/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/mixed_unpacked',
#  '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/CLEAN_subject_01_motive_down_right_period_8_amplitude_50_inst_1_2019_Aug_27_02_31_16PM.txt',
#  '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/CLEAN_subject_01_motive_down_left_period_8_amplitude_50_inst_1_2019_Aug_27_02_31_16PM.txt',
#  '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/CLEAN_subject_01_motive_just_right_period_8_amplitude_50_inst_1_2019_Aug_27_02_31_16PM.txt',
#  '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Personalized_Mapping/DATA/acquired_data/new_exp/CLEAN_subject_01_motive_just_up_period_8_amplitude_50_inst_1_2019_Aug_27_02_31_16PM.txt',
# ...
