# %% [markdown]
# # Analyse survey

# %% [markdown]
# ## Imports

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 16 13:02:17 2018

@author: macchini
"""

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import my_plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import utils

from numpy.random import seed
from numpy.random import randn
from scipy.stats import kruskal

from collections import Counter

# %% [markdown]
# ## Load file and create dataframe

# %%
folder = './Data'

files = os.listdir(folder)

surveys = [x for x in files if '.csv' in x]
print(surveys)

csv = surveys[1]
# Out:
# ['Bidirectional Interface - haptics.csv', 'Bidirectional Interface - learning.csv', 'NASA_TLX_haptics_1.csv', 'NASA_TLX_haptics_2.csv', 'NASA_TLX_haptics_3.csv', 'NASA_TLX_learn.csv']

# %%
answers_df = pd.read_csv(os.path.join(folder, csv))
answers_df
# Out:
#                       Horodateur  Age  Gender  \
# 0   2019/07/18 12:04:17 PM UTC+2   24    Male
# 1    2019/07/18 1:55:45 PM UTC+2   23    Male
# 2    2019/07/18 2:58:28 PM UTC+2   20    Male
# 3    2019/07/18 3:19:15 PM UTC+2   20    Male
# 4    2019/07/25 2:30:49 PM UTC+2   23    Male
# 5    2019/07/25 3:04:13 PM UTC+2   22  Female
# 6    2019/07/25 6:53:46 PM UTC+2   25    Male
# 7    2019/07/25 7:35:43 PM UTC+2   25  Female
# 8    2019/08/07 6:02:22 PM UTC+2   29  Female
# 9   2019/08/08 11:07:35 AM UTC+2   30    Male
# 10   2019/08/08 2:43:16 PM UTC+2   24  Female
# 11   2019/08/08 3:25:25 PM UTC+2   21    Male
# 12   2019/08/08 3:51:25 PM UTC+2   30    Male
# 13   2019/08/22 9:40:57 AM UTC+2   24    Male
# 14  2019/08/22 10:44:26 AM UTC+2   32    Male
# 15  2019/08/22 12:09:53 PM UTC+2   32  Female
# 16   2019/08/22 1:16:25 PM UTC+2   25    Male
# 17  2019/08/28 10:36:38 AM UTC+2   28    Male
# 18  2019/08/28 12:53:38 PM UTC+2   31    Male
# 19   2019/08/28 2:28:56 PM UTC+2   25  Female
# 20   2019/08/28 3:02:28 PM UTC+2   24    Male
# 21   2019/08/28 4:23:22 PM UTC+2   24    Male
#
#     How experienced are you with the use of remote controllers?  \
# 0                                                  10
# 1                                                   4
# 2                                                   4
# 3                                                   3
# 4                                                   7
# 5                                                   3
# 6                                                  10
# 7                                                   2
# 8                                                   9
# 9                                                   8
# 10                                                  2
# 11                                                 10
# 12                                                 10
# 13                                                 10
# 14                                                  5
# 15                                                  4
# 16                                                  8
# 17                                                  8
# 18                                                  5
# 19                                                  5
# 20                                                 10
# 21                                                  7
#
#     How experienced are you with the use of remote controllers for controlling drones?  \
# 0                                                   5
# 1                                                   1
# 2                                                   3
# 3                                                   2
# 4                                                   9
# 5                                                   2
# 6                                                   1
# 7                                                   1
# 8                                                   5
# 9                                                   7
# 10                                                  1
# 11                                                  1
# 12                                                  7
# 13                                                 10
# 14                                                  1
# 15                                                  2
# 16                                                  4
# 17                                                  9
# 18                                                  1
# 19                                                  1
# 20                                                  3
# 21                                                  1
#
#    Which interface was easier to use in the FIRST run?  \
# 0                                   Remote controller
# 1                                          Equivalent
# 2                                   Remote controller
# 3                                            Wearable
# 4                                   Remote controller
# 5                                            Wearable
# 6                                            Wearable
# 7                                   Remote controller
# 8                                          Equivalent
# 9                                            Wearable
# 10                                           Wearable
# 11                                  Remote controller
# 12                                           Wearable
# 13                                         Equivalent
# 14                                  Remote controller
# 15                                  Remote controller
# 16                                  Remote controller
# 17                                  Remote controller
# 18                                  Remote controller
# 19                                           Wearable
# 20                                  Remote controller
# 21                                           Wearable
#
#    Which interface was easier to use in the LAST run?  \
# 0                                            Wearable
# 1                                   Remote controller
# 2                                            Wearable
# 3                                            Wearable
# 4                                            Wearable
# 5                                            Wearable
# 6                                            Wearable
# 7                                            Wearable
# 8                                            Wearable
# 9                                            Wearable
# 10                                           Wearable
# 11                                  Remote controller
# 12                                           Wearable
# 13                                         Equivalent
# 14                                           Wearable
# 15                                  Remote controller
# 16                                  Remote controller
# 17                                           Wearable
# 18                                           Wearable
# 19                                           Wearable
# 20                                         Equivalent
# 21                                           Wearable
#
#    Which interface did you prefer?  \
# 0                          Werable
# 1                          Werable
# 2                          Werable
# 3                          Werable
# 4                          Werable
# 5                          Werable
# 6                          Werable
# 7                          Werable
# 8                          Werable
# 9                          Werable
# 10                         Werable
# 11               Remote controller
# 12                         Werable
# 13                         Werable
# 14                         Werable
# 15               Remote controller
# 16               Remote controller
# 17                         Werable
# 18                         Werable
# 19                         Werable
# 20                         Werable
# 21                         Werable
#
#                                                  Why?  \
# 0   Easier to mix different directions (up, left a...
# 1   Less sensible than the controller, therefore m...
# 2   The control is more natural with hand movement...
# 3   Le controle est plus naturel en position avec ...
# 4                                     more intuitive
# 5   easier to use. stops more quickly when need to...
# 6                                It is more intuitive
# 7            Werable is controlled with a single hand
# 8   more fun, more intuitive (I did not have to th...
# 9   The joystick had a mapping of the inputs/outpu...
# 10                                    Was easy to use
# 11  I have much more experience with the remote co...
# 12  I had an easier time understanding the control...
# 13                 It is cooler and more innovative.
# 14            naturally controlled with less thinking
# 15                the controlling is much more better
# 16  With the wearable controller, you have to pay ...
# 17  Because with the wearable you could make much ...
# 18        It seemed to be more natural after a while
# 19  It's easier to use it and to learn. The moveme...
# 20                   Wearable is much more fun to use
# 21                        more intuitive and more fun
#
#        Please give your personal feedback/impressions
# 0   At first Wearable was confusing because I trie...
# 1   I think there is a different input sensitivity...
# 2                                     Nice experience
# 3   le systeme wearable etait rapide a prendre en ...
# 4       i had to bring back my hand closed to my body
# 5   the obstacles at the back of the room were muc...
# 6   It feel nice to control with the wearable, but...
# 7   More inertia in the remote, maybe affected the...
# 8   I think that the gain of the wearable can be t...
# 9   In my opinion, the main problem related to the...
# 10                                               Nice
# 11  in the experiment, give more feedback about pa...
# 12            I never got the hang of the controller.
# 13  Controlling the drone with wearable control wa...
# 14          fun to control a drone with hand movement
# 15           not satisfied of the wearable controller
# 16  The drones could be more stable and control of...
# 17  I found the task easier with multiple tries an...
# 18  I prefer the wearable but it needs some effort...
# 19  The test starts on the right and my impression...
# 20  Wearable seemed more precise and definitely mo...
# 21  the controller had some inertia that took some...

# %% [markdown]
# ## Separate questions

# %%
data = {}

age = 'Age'
gender = 'Gender'
experience_controller = 'How experienced are you with the use of remote controllers?'
experience_controller_drone = 'How experienced are you with the use of remote controllers for controlling drones?'
easier_first = 'Which interface was easier to use in the FIRST run?'
easier_last = 'Which interface was easier to use in the LAST run?'
prefered = 'Which interface did you prefer?'

questions = [age, gender, experience_controller, experience_controller_drone, easier_first, easier_last, prefered]

for q in questions:
    data[q] = answers_df[q].values

# %% [markdown]
# ## Compute mean and average

# %%
stats = {}

mean_index = 0
std_index = 1

for q in [age, experience_controller, experience_controller_drone]:
    stats[q] = [0, 0]
    stats[q][mean_index] = np.mean(data[q])
    stats[q][std_index] = np.std(data[q])
        
print(stats)
# Out:
# {'Age': [25.5, 3.640054944640259], 'How experienced are you with the use of remote controllers?': [6.545454545454546, 2.8400907912387834], 'How experienced are you with the use of remote controllers for controlling drones?': [3.5, 2.981000442194472]}

# %% [markdown]
# ## Results

# %% [markdown]
# Stats (similarly for stats_hw for the hardware experiments) is a nested dictionnary containing the mean and std for each question of the survey, separated depending on the interface (remote or motion) and run (first or last)
#
# data (similarly data_hw) can be used to create boxplot for the distribution of answers.

# %%
plt.boxplot(data[age])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22966316dd8>,
#   <matplotlib.lines.Line2D at 0x22965b60438>],
#  'caps': [<matplotlib.lines.Line2D at 0x22965b60780>,
#   <matplotlib.lines.Line2D at 0x22965b60ac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22966316c88>],
#  'medians': [<matplotlib.lines.Line2D at 0x22965b60e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22965b60ef0>],
#  'means': []}

# %%
gender_pie_data = Counter(data[gender])
easier_first_pie_data = Counter(data[easier_first])
easier_last_pie_data = Counter(data[easier_last])
prefered_pie_data = Counter(data[prefered])

fig1, ax1 = plt.subplots()
ax1.pie(gender_pie_data.values(), labels=gender_pie_data.keys(), autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title(gender)

fig1, ax1 = plt.subplots()
ax1.pie(easier_first_pie_data.values(), labels=easier_first_pie_data.keys(), autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title(easier_first)

fig1, ax1 = plt.subplots()
ax1.pie(easier_last_pie_data.values(), labels=easier_last_pie_data.keys(), autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title(easier_last)

fig1, ax1 = plt.subplots()
ax1.pie(prefered_pie_data.values(), labels=prefered_pie_data.keys(), autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title(prefered)

plt.show()
