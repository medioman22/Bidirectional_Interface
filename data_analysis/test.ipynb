# %%
# %load_ext autoreload
# %autoreload 2

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import numpy as np
import pandas as pd
import seaborn as sn
import json
import glob, os
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
from numpy.random import seed
from scipy.stats import kruskal
from scipy.stats import levene

from termcolor import colored
import my_plots
from matplotlib.pylab import savefig

# %%
def dfFromCSV(file):
    df = pd.read_csv(file)

    df = df.drop(['Unnamed: 0', 'rosout__file', 'rosout__function', 'rosout__level', 'rosout__line', 'rosout__msg', 'rosout__name', 'rosout_agg__line', 'rosout_agg__msg', 'rosout_agg__name', 'rosout_agg__file', 'rosout_agg__function', 'rosout_agg__level'], axis=1)
    df = df.interpolate()
#     df = df.iloc[::20, :]
    df = df.dropna()
    return df

size = [4,4]

file = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Bidirectional_wearable_interface/DATA/rosbags/haptics/sub_4/remote/exp3/2019-08-27-10-47-55.csv'

log = dfFromCSV(file)

fig = plt.figure(figsize = [12,4])
ax = plt.subplot(1, 3, 1)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_x'])
plt.ylim(-4,4)
plt.grid()

ax = plt.subplot(1, 3, 2)
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_y'])
plt.ylim(-4,5)
plt.grid()

ax = plt.subplot(1, 3, 3)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.ylim(0,4)
plt.grid()

fig = plt.figure(figsize = [12,4])
ax = plt.subplot(1, 3, 1)
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_x'],-log['vrpn_client_node_cf1_pose__pose_position_y'])
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.grid()

ax = plt.subplot(1, 3, 2)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_x'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(0,4)
plt.grid()

ax = plt.subplot(1, 3, 3)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_y'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(0,4)
plt.grid()

fig = plt.figure(figsize = size)
ax = plt.subplot(1, 1, 1, projection='3d')
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_x'],-log['vrpn_client_node_cf1_pose__pose_position_y'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.grid()

# %%
def dfFromCSV(file):
    df = pd.read_csv(file)

    df = df.drop(['Unnamed: 0', 'rosout__file', 'rosout__function', 'rosout__level', 'rosout__line', 'rosout__msg', 'rosout__name', 'rosout_agg__line', 'rosout_agg__msg', 'rosout_agg__name', 'rosout_agg__file', 'rosout_agg__function', 'rosout_agg__level'], axis=1)
    df = df.interpolate()
#     df = df.iloc[::20, :]
    df = df.dropna()
    return df

size = [4,4]

log = dfFromCSV(file)

lim1 = 20000
lim2 = 30000

log = log[lim1:lim2]

fig = plt.figure(figsize = [12,4])
ax = plt.subplot(1, 3, 1)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_x'])
plt.ylim(-4,4)
plt.grid()

ax = plt.subplot(1, 3, 2)
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_y'])
plt.ylim(-4,5)
plt.grid()

ax = plt.subplot(1, 3, 3)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.ylim(0,4)
plt.grid()

fig = plt.figure(figsize = [12,4])
ax = plt.subplot(1, 3, 1)
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_x'],-log['vrpn_client_node_cf1_pose__pose_position_y'])
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.grid()

ax = plt.subplot(1, 3, 2)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_x'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(0,4)
plt.grid()

ax = plt.subplot(1, 3, 3)
ax.plot(log['vrpn_client_node_cf1_pose__pose_position_y'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(0,4)
plt.grid()

fig = plt.figure(figsize = size)
ax = plt.subplot(1, 1, 1, projection='3d')
ax.plot(-log['vrpn_client_node_cf1_pose__pose_position_x'],-log['vrpn_client_node_cf1_pose__pose_position_y'],log['vrpn_client_node_cf1_pose__pose_position_z'])
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.grid()

# %%
newfile = '/Volumes/GoogleDrive/My Drive/Matteo/EPFL/LIS/PhD/Bidirectional_wearable_interface/DATA/rosbags/haptics/sub_4/remote/exp2/4x.csv'
log.to_csv(newfile)
